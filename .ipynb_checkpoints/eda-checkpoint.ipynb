# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('salary_data_cleaned.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       742 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       742 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Competitors        742 non-null    object
#  14  min_salary         742 non-null    int64
#  15  max_salary         742 non-null    int64
# ...

# %%
df.same_state
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 737    0
# 738    0
# 739    1
# 740    0
# 741    0
# Name: same_state, Length: 742, dtype: int64

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'same_state',
#        'age', 'python', 'r_studio', 'spark', 'aws', 'excel', 'State'],
#       dtype='object')

# %%
#Simplifying title func
def title_simp(title):
    if 'data scientist' in title.lower() or 'data science' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analytics' in title.lower() or 'business intelligence' in title.lower() or 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower() :
        return 'ml'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    elif 'scientist' in title.lower():
        return 'scientist'
    else:
        return 'na'

#Seniority func
def sen(title):
    if 'sr' in title.lower() or 'sr.' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'junior' in title.lower():
        return 'junior'
    else:
        return 'na'

# %%
df['S Job Title']=df['Job Title'].apply(title_simp)

# %%
df['S Job Title'].value_counts()
# Out:
# data scientist    313
# scientist         143
# analyst           123
# data engineer     119
# ml                 22
# na                 15
# director            5
# manager             2
# Name: S Job Title, dtype: int64

# %%
df['Job Title']
# Out:
# 0                                         Data Scientist
# 1                              Healthcare Data Scientist
# 2                                         Data Scientist
# 3                                         Data Scientist
# 4                                         Data Scientist
#                              ...
# 737             Sr Scientist, Immuno-Oncology - Oncology
# 738                                 Senior Data Engineer
# 739    Project Scientist - Auton Lab, Robotics Institute
# 740                                 Data Science Manager
# 741            Research Scientist – Security and Privacy
# Name: Job Title, Length: 742, dtype: object

# %%
df['Seniority']=df['Job Title'].apply(sen)

# %%
df['Seniority'].value_counts()
# Out:
# na        519
# senior    220
# junior      3
# Name: Seniority, dtype: int64

# %%
df['State'].value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# CO     11
# DC     11
# IN     10
# UT     10
# WI     10
# MO      9
# AZ      9
# AL      8
# KY      6
# MI      6
# DE      6
# GA      6
# CT      5
# IA      5
# NE      4
# OR      4
# LA      4
# KS      3
# NM      3
# MN      2
# ID      2
# RI      1
# SC      1
# Name: State, dtype: int64

# %%
#job description length
df['jd_length']=df['Job Description'].apply(lambda x: len(x))

# %%
df.describe()
# Out:
#            Rating      Founded  min_salary  max_salary  avg_salary  \
# count  742.000000   742.000000  742.000000  742.000000  742.000000
# mean     3.618868  1837.154987   74.068733  127.183288  100.626011
# std      0.801210   497.183763   31.869282   46.909006   38.855948
# min     -1.000000    -1.000000   10.000000   16.000000   13.500000
# 25%      3.300000  1939.000000   52.000000   96.000000   73.500000
# 50%      3.700000  1988.000000   69.500000  124.000000   97.500000
# 75%      4.000000  2007.000000   91.000000  155.000000  122.500000
# max      5.000000  2019.000000  202.000000  306.000000  254.000000
#
#        same_state         age      python    r_studio       spark         aws  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean     0.557951   46.726415    0.528302    0.002695    0.225067    0.237197
# std      0.496965   53.661601    0.499535    0.051882    0.417908    0.425651
# ...

# %%
sns.histplot(data=df['Rating'], color='red')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(data=df['avg_salary'], color='orange', bins=20)
# Out:
# <AxesSubplot:xlabel='avg_salary', ylabel='Count'>

# %%
sns.histplot(data=df['age'], color='blue', bins=15)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df['jd_length'], color='blue', bins=15)
# Out:
# <AxesSubplot:xlabel='jd_length', ylabel='Count'>

# %%
sns.boxplot(data=df[['age', 'avg_salary']])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df['Rating'])
# Out:
# <AxesSubplot:>

# %%
df[['age', 'avg_salary', 'Rating', 'jd_length']].corr()
# Out:
#                  age  avg_salary    Rating  jd_length
# age         1.000000    0.019817  0.018630   0.163344
# avg_salary  0.019817    1.000000  0.013492   0.078808
# Rating      0.018630    0.013492  1.000000  -0.012281
# jd_length   0.163344    0.078808 -0.012281   1.000000

# %%
sns.heatmap(data=df[['age', 'avg_salary', 'Rating', 'jd_length']].corr(), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'same_state',
#        'age', 'python', 'r_studio', 'spark', 'aws', 'excel', 'State',
#        'S Job Title', 'Seniority', 'jd_length'],
#       dtype='object')

# %%
df_cat=df[['Company Name', 'Location', 'Headquarters', 'company_txt', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'State', 'python', 'r_studio', 'spark', 'aws', 'excel', 'S Job Title', 'Seniority']]

# %%
df_cat.head()
# Out:
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#      Headquarters                            company_txt  \
# 0      Goleta, CA                      Tecolote Research
# 1   Baltimore, MD  University of Maryland Medical System
# 2  Clearwater, FL                                KnowBe4
# 3    Richland, WA                                   PNNL
# 4    New York, NY                     Affinity Solutions
#
#                      Size   Type of ownership  \
# 0   501 to 1000 employees   Company - Private
# 1        10000+ employees  Other Organization
# 2   501 to 1000 employees   Company - Private
# 3  1001 to 5000 employees          Government
# ...

# %%
for i in df_cat.columns:
    cat_num=df_cat[i].value_counts()
    print('Graph for %s : Total = %d' % (i, len(cat_num)))
    plt.figure(figsize=(15,5))
    sns.barplot(x=cat_num.index, y=cat_num)
    plt.xticks(rotation=90)    
    plt.show()
# Out:
# Graph for Company Name : Total = 343
# Graph for Location : Total = 200
# Graph for Headquarters : Total = 198
# Graph for company_txt : Total = 343
# Graph for Size : Total = 9
# Graph for Type of ownership : Total = 11
# Graph for Industry : Total = 60
# Graph for Sector : Total = 25
# Graph for Revenue : Total = 14
# Graph for State : Total = 37
# Graph for python : Total = 2
# Graph for r_studio : Total = 2
# Graph for spark : Total = 2
# Graph for aws : Total = 2
# Graph for excel : Total = 2
# Graph for S Job Title : Total = 8
# Graph for Seniority : Total = 3

# %%
for i in df[['Location', 'Headquarters', 'company_txt']].columns:
    cat_num=df_cat[i].value_counts()[:20]
    print('Graph for %s : Total = %d' % (i, len(cat_num)))
    plt.figure(figsize=(15,5))
    sns.barplot(x=cat_num.index, y=cat_num)
    plt.xticks(rotation=90)    
    plt.show()
# Out:
# Graph for Location : Total = 20
# Graph for Headquarters : Total = 20
# Graph for company_txt : Total = 20

# %%
pd.pivot_table(df, index='S Job Title', values='avg_salary')
# Out:
#                 avg_salary
# S Job Title
# analyst          66.703252
# data engineer   105.403361
# data scientist  118.293930
# director        130.800000
# manager          85.250000
# ml              126.431818
# na               86.800000
# scientist        83.797203

# %%
pd.pivot_table(df, index=['S Job Title', 'Seniority'], values='avg_salary')
# Out:
#                           avg_salary
# S Job Title    Seniority
# analyst        junior      53.250000
#                na          63.430851
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist junior     106.500000
#                na         110.191038
#                senior     135.590000
# director       na         130.800000
# manager        na          85.250000
# ml             na         119.133333
#                senior     142.071429
# na             na          85.846154
#                senior      93.000000
# scientist      na          70.078125
#                senior     111.819149

# %%
pd.pivot_table(df, index=['State', 'S Job Title'], values='avg_salary').sort_values('avg_salary', ascending=False)
# Out:
#                       avg_salary
# State S Job Title
# CA    ml              177.300000
# DC    data scientist  149.000000
# IL    data scientist  147.095238
# CA    data scientist  141.047297
# UT    data scientist  140.500000
# ...                          ...
# CO    scientist        31.500000
#       analyst          29.500000
# DE    scientist        27.500000
# LA    scientist        20.000000
# TN    analyst          13.500000
#
# [115 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'same_state',
#        'age', 'python', 'r_studio', 'spark', 'aws', 'excel', 'State',
#        'S Job Title', 'Seniority', 'jd_length'],
#       dtype='object')

# %%
df_pivots=df[['Rating','Industry', 'Sector', 'Revenue', 'python', 'r_studio', 'spark', 'aws', 'excel','avg_salary']]

# %%
for i in df_pivots.columns[:-1]:
    print(i)
    print(pd.pivot_table(df_pivots, index= i, values= 'avg_salary').sort_values('avg_salary', ascending=False))
    print(end='\n')
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
#
# Industry
#                                           avg_salary
# Industry
# Other Retail Stores                       163.500000
# Motion Picture Production & Distribution  146.000000
# Financial Analytics & Research            145.125000
# Health, Beauty, & Fitness                 139.500000
# ...

# %%
pd.pivot_table(df_pivots, index= 'Revenue', columns='python', values= 'avg_salary', aggfunc= 'count')
# Out:
# python                               0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'same_state',
#        'age', 'python', 'r_studio', 'spark', 'aws', 'excel', 'State',
#        'S Job Title', 'Seniority', 'jd_length'],
#       dtype='object')

# %%
# Python program to generate WordCloud
  
# importing all necessery modules
from wordcloud import WordCloud, STOPWORDS

  
comment_words = ''
stopwords = set(STOPWORDS)
  
# iterate through the csv file
for val in df['Job Description']:
      
    # typecaste each val to string
    val = str(val)
  
    # split the value
    tokens = val.split()
      
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (6, 10), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()
